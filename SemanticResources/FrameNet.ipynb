# %%
import nltk
import hashlib
import random
from random import randint
from random import seed
from nltk.corpus import framenet as fn
from nltk.corpus import stopwords
from nltk.tokenize import WhitespaceTokenizer
from nltk.corpus import wordnet
from nltk.corpus.reader.wordnet import Synset

nltk.download('framenet_v17')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package framenet_v17 to /root/nltk_data...
# [nltk_data]   Package framenet_v17 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
def print_frames_with_IDs():
    for x in fn.frames():
        print('{}\t{}'.format(x.ID, x.name))

def get_frams_IDs():
    return [f.ID for f in fn.frames()]

def cool_string_hashcode(string): 
    return abs(int(hashlib.sha512(string.encode('utf-8')).hexdigest(), 16))

def get_frame_set_for_student(surname, list_len=5):
    nof_frames = len(fn.frames())
    base_idx = (cool_string_hashcode(surname) % nof_frames)
    print('Student: ' + surname)
    framenet_IDs = get_frams_IDs()
    i = 0
    offset = 0 
    seed(1)
    frames = []
    while i < list_len:
        fID = framenet_IDs[(base_idx+offset)%nof_frames]
        f = fn.frame(fID)
        frames.append(f)
        fNAME = f.name
        print('\tID: {a:4d}\tframe: {framename}'.format(a=fID, framename=fNAME))
        offset = randint(0, nof_frames)
        i += 1 
    return frames

# %%
def flat_map_strings(list, tokenizer = WhitespaceTokenizer()):
    ret = []
    for s in list:
        for w in tokenizer.tokenize(s):
            ret.append(w)
    return ret

# %%
def get_context_from_frame(frame):
    raw_data = []
    raw_data.append(frame["name"].replace("_", " "))
    raw_data.append(frame["definition"])
    for _, le in frame["lexUnit"].items():
        raw_data.append(le["name"].split('.')[0])
        raw_data.append(le["definition"])
        for example in le["exemplars"]:
            raw_data.append(example["text"])
    for _, fe in frame["FE"].items():
        raw_data.append(fe["definition"])
        raw_data.append(fe["name"])
    return set(flat_map_strings(raw_data))

# %%
def get_context_from_synset(synset):
    raw_data = []
    raw_data.append(synset.definition())
    for e in synset.examples():
        raw_data.append(e)
    for l in synset.lemma_names():
        raw_data.append(l)
    return set(flat_map_strings(raw_data))

# %%
def compare_and_score_contexts(ctx1, ctx2):
     return len(ctx1.intersection(ctx2)) + 1

# %%
def find_best_meaning(lemma, lemma_ctx):
    best_score = 0
    best_synset = None
    for synset in wordnet.synsets(lemma):
        synset_ctx = get_context_from_synset(synset)
        score = compare_and_score_contexts(synset_ctx, lemma_ctx)
        if (score > best_score):
            best_synset = synset
            best_score = score
    return best_synset if best_synset is not None else Synset(None)

# %%
def select_most_important_word(words):
    best = 0
    tag = nltk.tag.pos_tag(words)
    for i in range(0, len(words)):
        if tag[i] == 'VERB':
            return words[i]
        elif tag[i] == 'NOUN' and tag[best] != 'NOUN':
           best = i
    return words[best]

def smiw(words):
    return select_most_important_word(words)

# %%
def disambiguate_frame_data(frame):
    frame_ctx = get_context_from_frame(frame)
    best_frame_name_word = smiw(frame["name"].split("_"))
    title_best_meaning = find_best_meaning(best_frame_name_word, frame_ctx)
    print(f'\nTitle disambiguation: {frame["name"]} | best synset: {title_best_meaning}')
    print(f'Synset definition: {title_best_meaning.definition()}')
    print("Frame elements disambiguations:")
    count = 0

    for _, fe in frame["FE"].items():
        best_fe_name_word = smiw(fe["name"].split("_"))
        fe_best_meaning = find_best_meaning(best_fe_name_word, frame_ctx)
        print(f' - {fe["name"]} | best synset: {fe_best_meaning}')
        print(f'   Synset definition: {fe_best_meaning.definition()}')

    print("Lexical units disambiguations:")
    count = 0
    for _, le in frame["lexUnit"].items():
        le_best_meaning = find_best_meaning(le["name"].split(".")[0], frame_ctx)
        print(f' - {le["name"]} | best synset: {le_best_meaning}')
        print(f'   Synset definition: {le_best_meaning.definition()}')
    return

# %%
for f in get_frame_set_for_student("Basti"):
    disambiguate_frame_data(f)
    print("________________________________________________")
# Out:
# Student: Basti
# 	ID:  810	frame: Measure_by_action
# 	ID:  347	frame: Revenge
# 	ID: 1041	frame: Left_to_do
# 	ID: 1182	frame: Post_receiving
# 	ID: 1322	frame: Active_substance
#
# Title disambiguation: Measure_by_action | best synset: Synset('measure.v.04')
# Synset definition: evaluate or estimate the nature, quality, ability, extent, or significance of
# Frame elements disambiguations:
#  - Entity | best synset: Synset('entity.n.01')
#    Synset definition: that which is perceived or known or inferred to have its own distinct existence (living or nonliving)
#  - Event | best synset: Synset('consequence.n.01')
#    Synset definition: a phenomenon that follows and is caused by some previous phenomenon
#  - Count | best synset: Synset('count.v.08')
#    Synset definition: have faith or confidence in
#  - Particular_iteration | best synset: Synset('detail.n.02')
#    Synset definition: a small part that can be considered separately from the whole
# Lexical units disambiguations:
#  - splash.n | best synset: Synset('dab.n.02')
#    Synset definition: a small quantity of something moist or liquid
#  - bite.n | best synset: Synset('bite.n.05')
#    Synset definition: (angling) an instance of a fish taking the bait
#  - pinch.n | best synset: Synset('emergency.n.01')
#    Synset definition: a sudden unforeseen crisis (usually involving danger) that requires immediate action
# ________________________________________________
#
# Title disambiguation: Revenge | best synset: Synset('revenge.v.01')
# Synset definition: take revenge for a perceived wrong
# Frame elements disambiguations:
#  - Avenger | best synset: Synset('avenger.n.01')
#    Synset definition: someone who takes vengeance
#  - Degree | best synset: Synset('academic_degree.n.01')
#    Synset definition: an award conferred by a college or university signifying that the recipient has satisfactorily completed a course of study
#  - Depictive | best synset: Synset('delineative.s.01')
#    Synset definition: depicted in a recognizable manner
#  - Offender | best synset: Synset('wrongdoer.n.01')
#    Synset definition: a person who transgresses moral or civil law
#  - Instrument | best synset: Synset('instrument.n.02')
#    Synset definition: the means whereby some act is accomplished
#  - Manner | best synset: Synset('manner.n.01')
#    Synset definition: how something is done or how it happens
#  - Punishment | best synset: Synset('punishment.n.01')
#    Synset definition: the act of punishing
#  - Place | best synset: Synset('put.v.01')
#    Synset definition: put into a certain place or abstract location
#  - Purpose | best synset: Synset('purpose.n.01')
#    Synset definition: an anticipated outcome that is intended or that guides your planned actions
#  - Injury | best synset: Synset('injury.n.01')
#    Synset definition: any physical damage to the body caused by violence or accident or fracture etc.
#  - Result | best synset: Synset('consequence.n.01')
#    Synset definition: a phenomenon that follows and is caused by some previous phenomenon
#  - Time | best synset: Synset('time.n.02')
#    Synset definition: a period of time considered as a resource under your control and sufficient to accomplish something
#  - Injured_party | best synset: Synset('hurt.v.05')
#    Synset definition: hurt the feelings of
#  - Duration | best synset: Synset('duration.n.03')
#    Synset definition: continuance in time
# Lexical units disambiguations:
#  - avenge.v | best synset: Synset('revenge.v.01')
#    Synset definition: take revenge for a perceived wrong
#  - avenger.n | best synset: Synset('avenger.n.01')
#    Synset definition: someone who takes vengeance
#  - vengeance.n | best synset: Synset('vengeance.n.01')
#    Synset definition: the act of taking revenge (harming someone in retaliation for something harmful that they have done) especially in the next life; I will repay, saith the Lord"--Romans 12:19
#  - retaliate.v | best synset: Synset('retaliate.v.02')
#    Synset definition: make a counterattack and return like for like, especially evil for evil
#  - revenge.v | best synset: Synset('revenge.v.01')
#    Synset definition: take revenge for a perceived wrong
#  - revenge.n | best synset: Synset('revenge.v.01')
#    Synset definition: take revenge for a perceived wrong
#  - vengeful.a | best synset: Synset('revengeful.s.01')
#    Synset definition: disposed to seek revenge or intended for revenge
#  - vindictive.a | best synset: Synset('despiteful.s.01')
#    Synset definition: showing malicious ill will and a desire to hurt; motivated by spite
#  - retribution.n | best synset: Synset('vengeance.n.01')
#    Synset definition: the act of taking revenge (harming someone in retaliation for something harmful that they have done) especially in the next life; I will repay, saith the Lord"--Romans 12:19
#  - retaliation.n | best synset: Synset('retaliation.n.01')
#    Synset definition: action taken in return for an injury or offense
#  - revenger.n | best synset: Synset('None')
#    Synset definition: None
#  - revengeful.a | best synset: Synset('revengeful.s.01')
#    Synset definition: disposed to seek revenge or intended for revenge
#  - retributive.a | best synset: Synset('retaliatory.s.01')
#    Synset definition: of or relating to or having the nature of retribution
#  - get even.v | best synset: Synset('None')
#    Synset definition: None
#  - retributory.a | best synset: Synset('retaliatory.s.01')
#    Synset definition: of or relating to or having the nature of retribution
#  - get back (at).v | best synset: Synset('None')
#    Synset definition: None
#  - payback.n | best synset: Synset('vengeance.n.01')
#    Synset definition: the act of taking revenge (harming someone in retaliation for something harmful that they have done) especially in the next life; I will repay, saith the Lord"--Romans 12:19
#  - sanction.n | best synset: Synset('authority.n.06')
#    Synset definition: official permission or approval
# ________________________________________________
#
# Title disambiguation: Left_to_do | best synset: Synset('left.a.01')
# Synset definition: being or located on or directed toward the side of the body to the west when facing north
# Frame elements disambiguations:
#  - Process | best synset: Synset('process.v.01')
#    Synset definition: subject to a process or treatment, with the aim of readying for some purpose, improving, or remedying a condition
#  - Remainder | best synset: Synset('end.n.13')
#    Synset definition: a piece of cloth that is left over after the rest has been used or sold
#  - Time | best synset: Synset('time.v.05')
#    Synset definition: adjust so that a force is applied and an action occurs at the desired time
#  - Agent | best synset: Synset('agent.n.02')
#    Synset definition: a representative who acts on behalf of other persons or organizations
# Lexical units disambiguations:
#  - left.a | best synset: Synset('left.a.01')
#    Synset definition: being or located on or directed toward the side of the body to the west when facing north
#  - remain.v | best synset: Synset('stay.v.01')
#    Synset definition: stay the same; remain in a certain state
#  - remainder.n | best synset: Synset('end.n.13')
#    Synset definition: a piece of cloth that is left over after the rest has been used or sold
# ________________________________________________
#
# Title disambiguation: Post_receiving | best synset: Synset('post.n.09')
# Synset definition: a pole or stake set up to mark something (as the start or end of a race track)
# Frame elements disambiguations:
#  - Recipient | best synset: Synset('recipient_role.n.01')
#    Synset definition: the semantic role of the animate entity that is passively involved in the happening denoted by the verb in the clause
#  - Donor | best synset: Synset('donor.n.02')
#    Synset definition: (medicine) someone who gives blood or tissue or an organ to be used in another person (the host)
#  - Theme | best synset: Synset('theme.n.03')
#    Synset definition: (music) melodic subject of a musical composition
#  - Manner | best synset: Synset('manner.n.01')
#    Synset definition: how something is done or how it happens
#  - Time | best synset: Synset('clock.v.01')
#    Synset definition: measure the time or duration of an event or action or the person who performs an action in a certain period of time
# Lexical units disambiguations:
# ________________________________________________
#
# Title disambiguation: Active_substance | best synset: Synset('active.a.03')
# Synset definition: disposed to take action or effectuate change
# Frame elements disambiguations:
#  - Effect | best synset: Synset('consequence.n.01')
#    Synset definition: a phenomenon that follows and is caused by some previous phenomenon
#  - Substance | best synset: Synset('substance.n.07')
#    Synset definition: a particular kind or species of matter with uniform properties
#  - Descriptor | best synset: Synset('descriptor.n.02')
#    Synset definition: a piece of stored information that is used to identify an item in an information storage and retrieval system
#  - Type | best synset: Synset('type.n.06')
#    Synset definition: a small metal block bearing a raised character on one end; produces a printed character when inked and pressed on paper
#  - Name | best synset: Synset('name.n.04')
#    Synset definition: a well-known or notable person
# Lexical units disambiguations:
#  - agent.n | best synset: Synset('agent.n.01')
#    Synset definition: an active and efficient cause; capable of producing a certain effect
#  - active.a | best synset: Synset('active.a.03')
#    Synset definition: disposed to take action or effectuate change
#  - bioactive.a | best synset: Synset('None')
#    Synset definition: None
#  - causative agent.n | best synset: Synset('None')
#    Synset definition: None
#  - irritant.n | best synset: Synset('irritant.n.01')
#    Synset definition: something that causes irritation and annoyance
#  - incapacitant.n | best synset: Synset('None')
#    Synset definition: None
# ________________________________________________

# %%
for f in get_frame_set_for_student("Pregno"):
    disambiguate_frame_data(f)
    print("________________________________________________")
# Out:
# Student: Pregno
# 	ID:    5	frame: Causation
# 	ID:  384	frame: Experience_bodily_harm
# 	ID:  228	frame: Being_named
# 	ID: 2654	frame: Controller_object
# 	ID:  156	frame: Measure_area
#
# Title disambiguation: Causation | best synset: Synset('causing.n.01')
# Synset definition: the act of causing something to happen
# Frame elements disambiguations:
#  - Cause | best synset: Synset('campaign.n.02')
#    Synset definition: a series of actions advancing a principle or tending toward a particular end
#  - Affected | best synset: Synset('feign.v.01')
#    Synset definition: make believe with the intent to deceive
#  - Effect | best synset: Synset('consequence.n.01')
#    Synset definition: a phenomenon that follows and is caused by some previous phenomenon
#  - Place | best synset: Synset('put.v.01')
#    Synset definition: put into a certain place or abstract location
#  - Time | best synset: Synset('time.n.02')
#    Synset definition: a period of time considered as a resource under your control and sufficient to accomplish something
#  - Actor | best synset: Synset('actor.n.02')
#    Synset definition: a person who acts and gets things done
#  - Circumstances | best synset: Synset('fortune.n.04')
#    Synset definition: your overall circumstances or condition in life (including everything that happens to you)
#  - Manner | best synset: Synset('manner.n.01')
#    Synset definition: how something is done or how it happens
#  - Explanation | best synset: Synset('explanation.n.01')
#    Synset definition: a statement that makes something comprehensible by describing the relevant structure or operation or circumstances etc.
#  - Means | best synset: Synset('intend.v.01')
#    Synset definition: have in mind as a purpose
#  - Frequency | best synset: Synset('frequency.n.01')
#    Synset definition: the number of occurrences within a given time period
#  - Concessive | best synset: Synset('concessive.a.01')
#    Synset definition: of or pertaining to concession
# Lexical units disambiguations:
#  - cause.v | best synset: Synset('campaign.n.02')
#    Synset definition: a series of actions advancing a principle or tending toward a particular end
#  - cause.n | best synset: Synset('campaign.n.02')
#    Synset definition: a series of actions advancing a principle or tending toward a particular end
#  - make.v | best synset: Synset('gain.v.08')
#    Synset definition: earn on some commercial or business transaction; earn as salary or wages
#  - lead (to).v | best synset: Synset('None')
#    Synset definition: None
#  - reason.n | best synset: Synset('rationality.n.01')
#    Synset definition: the state of having good sense and sound judgment
#  - send.v | best synset: Synset('send.v.01')
#    Synset definition: cause to go somewhere
#  - bring about.v | best synset: Synset('None')
#    Synset definition: None
#  - precipitate.v | best synset: Synset('hasty.s.02')
#    Synset definition: done with very great haste and without due deliberation
#  - causative.a | best synset: Synset('causative.a.01')
#    Synset definition: producing an effect
#  - render.v | best synset: Synset('translate.v.01')
#    Synset definition: restate (words) from one language into another language
#  - bring.v | best synset: Synset('bring.v.02')
#    Synset definition: cause to come into a particular state or condition
#  - bring on.v | best synset: Synset('None')
#    Synset definition: None
#  - induce.v | best synset: Synset('induce.v.02')
#    Synset definition: cause to do; cause to act in a specified manner
#  - wreak.v | best synset: Synset('bring.v.03')
#    Synset definition: cause to happen or to occur as a consequence
#  - put.v | best synset: Synset('put.v.04')
#    Synset definition: attribute or give
#  - since.c | best synset: Synset('None')
#    Synset definition: None
#  - because.c | best synset: Synset('None')
#    Synset definition: None
#  - because of.prep | best synset: Synset('None')
#    Synset definition: None
#  - raise.v | best synset: Synset('promote.v.02')
#    Synset definition: give a promotion to or assign to a higher position
#  - result (in).v | best synset: Synset('None')
#    Synset definition: None
#  - mean.v | best synset: Synset('base.s.05')
#    Synset definition: having or showing an ignoble lack of honor or morality
#  - result.n | best synset: Synset('consequence.n.01')
#    Synset definition: a phenomenon that follows and is caused by some previous phenomenon
#  - leave.v | best synset: Synset('leave.v.02')
#    Synset definition: go and leave behind, either intentionally or by neglect or forgetfulness
#  - for.c | best synset: Synset('None')
#    Synset definition: None
#  - see.v | best synset: Synset('determine.v.08')
#    Synset definition: find out, learn, or determine with certainty, usually by making an inquiry or other effort
#  - force.v | best synset: Synset('force.n.03')
#    Synset definition: physical energy or intensity
#  - give rise.v | best synset: Synset('None')
#    Synset definition: None
#  - so.c | best synset: Synset('therefore.r.01')
#    Synset definition: (used to introduce a logical conclusion) from that fact or reason or as a result
#  - due to.prep | best synset: Synset('None')
#    Synset definition: None
#  - responsible.a | best synset: Synset('responsible.a.01')
#    Synset definition: worthy of or requiring responsibility or trust; or held accountable
#  - consequence.n | best synset: Synset('consequence.n.01')
#    Synset definition: a phenomenon that follows and is caused by some previous phenomenon
#  - resulting.a | best synset: Synset('leave.v.07')
#    Synset definition: have as a result or residue
#  - consequent.a | best synset: Synset('attendant.s.02')
#    Synset definition: following or accompanying as a consequence
#  - consequential.a | best synset: Synset('consequential.s.01')
#    Synset definition: having important issues or results
#  - resultant.a | best synset: Synset('attendant.s.02')
#    Synset definition: following or accompanying as a consequence
#  - dictate.v | best synset: Synset('dictate.v.02')
#    Synset definition: say out loud for the purpose of recording
#  - motivate.v | best synset: Synset('motivate.v.01')
#    Synset definition: give an incentive for action
#  - sway.v | best synset: Synset('carry.v.23')
#    Synset definition: win approval or support for
#  - legacy.n | best synset: Synset('bequest.n.01')
#    Synset definition: (law) a gift of personal property by will
# ________________________________________________
#
# Title disambiguation: Experience_bodily_harm | best synset: Synset('know.v.05')
# Synset definition: have firsthand knowledge of states, situations, emotions, or sensations
# Frame elements disambiguations:
#  - Body_part | best synset: Synset('body.n.01')
#    Synset definition: the entire structure of an organism (an animal, plant, or human being)
#  - Containing_event | best synset: Synset('incorporate.v.02')
#    Synset definition: include or contain; have as a component
#  - Manner | best synset: Synset('manner.n.01')
#    Synset definition: how something is done or how it happens
#  - Place | best synset: Synset('put.v.01')
#    Synset definition: put into a certain place or abstract location
#  - Experiencer | best synset: Synset('None')
#    Synset definition: None
#  - Time | best synset: Synset('time.v.05')
#    Synset definition: adjust so that a force is applied and an action occurs at the desired time
#  - Injuring_entity | best synset: Synset('hurt.v.05')
#    Synset definition: hurt the feelings of
#  - Severity | best synset: Synset('badness.n.02')
#    Synset definition: used of the degree of something undesirable e.g. pain or weather
#  - Iterations | best synset: Synset('iteration.n.02')
#    Synset definition: (computer science) executing the same set of instructions a given number of times or until a specified result is obtained
#  - Duration | best synset: Synset('duration.n.01')
#    Synset definition: the period of time during which something continues
#  - Frequency | best synset: Synset('frequency.n.01')
#    Synset definition: the number of occurrences within a given time period
# Lexical units disambiguations:
#  - stub.v | best synset: Synset('stub.v.04')
#    Synset definition: strike (one's toe) accidentally against an object
#  - jam.v | best synset: Synset('fix.n.01')
#    Synset definition: informal terms for a difficult situation
#  - hit.v | best synset: Synset('hit.v.05')
#    Synset definition: affect or afflict suddenly, usually adversely
#  - hurt.v | best synset: Synset('hurt.v.05')
#    Synset definition: hurt the feelings of
#  - injure.v | best synset: Synset('hurt.v.05')
#    Synset definition: hurt the feelings of
#  - break.v | best synset: Synset('unwrap.v.02')
#    Synset definition: make known to the public information that was previously known only to a few people or that was meant to be kept a secret
#  - sprain.v | best synset: Synset('twist.v.10')
#    Synset definition: twist suddenly so as to sprain
#  - strain.v | best synset: Synset('strain.n.04')
#    Synset definition: (psychology) nervousness resulting from mental stress
#  - twist.v | best synset: Synset('twist.v.10')
#    Synset definition: twist suddenly so as to sprain
#  - pull.v | best synset: Synset('wrench.n.01')
#    Synset definition: a sharp strain on muscles or ligaments
#  - tear.v | best synset: Synset('rip.n.02')
#    Synset definition: an opening made forcibly as by pulling apart
#  - cut.v | best synset: Synset('cut.a.01')
#    Synset definition: separated into parts or laid open or penetrated with a sharp edge or instrument
#  - burn.v | best synset: Synset('bite.v.02')
#    Synset definition: cause a sharp or stinging pain or discomfort
#  - smack.v | best synset: Synset('smack.n.03')
#    Synset definition: a sailing ship (usually rigged like a sloop or cutter) used in fishing and sailing along the coast
#  - abrade.v | best synset: Synset('scour.v.03')
#    Synset definition: rub hard or scrub
#  - graze.v | best synset: Synset('browse.v.04')
#    Synset definition: eat lightly, try different dishes
#  - bruise.v | best synset: Synset('hurt.v.05')
#    Synset definition: hurt the feelings of
#  - scrape.v | best synset: Synset('scrape.n.03')
#    Synset definition: a deep bow with the foot drawn backwards (indicating excessive humility)
#  - sunburn.v | best synset: Synset('tan.n.01')
#    Synset definition: a browning of the skin resulting from exposure to the rays of the sun
#  - injury.n | best synset: Synset('injury.n.01')
#    Synset definition: any physical damage to the body caused by violence or accident or fracture etc.
# ________________________________________________
#
# Title disambiguation: Being_named | best synset: Synset('be.v.05')
# Synset definition: happen, occur, take place; this was during the visit to my parents' house"
# Frame elements disambiguations:
#  - Name | best synset: Synset('name.n.01')
#    Synset definition: a language unit by which a person or thing is known
#  - Entity | best synset: Synset('entity.n.01')
#    Synset definition: that which is perceived or known or inferred to have its own distinct existence (living or nonliving)
#  - Language | best synset: Synset('language.n.01')
#    Synset definition: a systematic means of communicating by the use of sounds or conventional symbols
#  - Type | best synset: Synset('type.n.06')
#    Synset definition: a small metal block bearing a raised character on one end; produces a printed character when inked and pressed on paper
#  - Descriptor | best synset: Synset('form.n.01')
#    Synset definition: the phonological or orthographic sound or appearance of a word that can be used to describe or identify something
#  - Context | best synset: Synset('context.n.02')
#    Synset definition: the set of facts or circumstances that surround a situation or event
#  - Etymological_root | best synset: Synset('etymological.a.01')
#    Synset definition: based on or belonging to etymology
# Lexical units disambiguations:
#  - pseudonym.n | best synset: Synset('pseudonym.n.01')
#    Synset definition: a fictitious name used when the person performs a particular social role
#  - name.n | best synset: Synset('name.n.01')
#    Synset definition: a language unit by which a person or thing is known
#  - nickname.n | best synset: Synset('nickname.n.01')
#    Synset definition: a familiar name for a person (often a shortened version of a person's given name)
#  - surname.n | best synset: Synset('surname.n.01')
#    Synset definition: the name used to identify the members of a family (as distinguished from each member's given name)
#  - forename.n | best synset: Synset('first_name.n.01')
#    Synset definition: the name that precedes the surname
#  - maiden name.n | best synset: Synset('None')
#    Synset definition: None
#  - Christian name.n | best synset: Synset('None')
#    Synset definition: None
#  - family name.n | best synset: Synset('None')
#    Synset definition: None
#  - nom de plume.n | best synset: Synset('None')
#    Synset definition: None
#  - nom de guerre.n | best synset: Synset('None')
#    Synset definition: None
#  - moniker.n | best synset: Synset('nickname.n.01')
#    Synset definition: a familiar name for a person (often a shortened version of a person's given name)
#  - pen name.n | best synset: Synset('None')
#    Synset definition: None
#  - first name.n | best synset: Synset('None')
#    Synset definition: None
#  - last name.n | best synset: Synset('None')
#    Synset definition: None
#  - middle name.n | best synset: Synset('None')
#    Synset definition: None
#  - stage name.n | best synset: Synset('None')
#    Synset definition: None
#  - alias.n | best synset: Synset('alias.r.01')
#    Synset definition: as known or named at another time or place
#  - given name.n | best synset: Synset('None')
#    Synset definition: None
#  - entitled.a | best synset: Synset('entitled.s.01')
#    Synset definition: qualified for by right according to law
#  - named.a | best synset: Synset('name.v.02')
#    Synset definition: give the name or identifying characteristics of; refer to by name or some other identifying characteristic property
#  - codename.n | best synset: Synset('None')
#    Synset definition: None
#  - codenamed.a | best synset: Synset('None')
#    Synset definition: None
#  - pet name.n | best synset: Synset('None')
#    Synset definition: None
#  - cognomen.n | best synset: Synset('nickname.n.01')
#    Synset definition: a familiar name for a person (often a shortened version of a person's given name)
#  - agnomen.n | best synset: Synset('agnomen.n.01')
#    Synset definition: an additional name or an epithet appended to a name (as in `Ferdinand the Great')
#  - by-name.n | best synset: Synset('None')
#    Synset definition: None
#  - caconym.n | best synset: Synset('None')
#    Synset definition: None
#  - praenomen.n | best synset: Synset('praenomen.n.01')
#    Synset definition: the first name of a citizen of ancient Rome
#  - misnomer.n | best synset: Synset('misnomer.n.01')
#    Synset definition: an incorrect or unsuitable name
#  - married name.n | best synset: Synset('None')
#    Synset definition: None
#  - allonym.n | best synset: Synset('None')
#    Synset definition: None
#  - soubriquet.n | best synset: Synset('nickname.n.01')
#    Synset definition: a familiar name for a person (often a shortened version of a person's given name)
#  - nee.a | best synset: Synset('nee.s.01')
#    Synset definition: (meaning literally `born') used to indicate the maiden or family name of a married woman
#  - brand name.n | best synset: Synset('None')
#    Synset definition: None
#  - patronymic.n | best synset: Synset('patronymic.n.01')
#    Synset definition: a family name derived from name of your father or a paternal ancestor (especially with an affix (such as -son in English or O'- in Irish) added to the name of your father or a paternal ancestor)
#  - metronymic.n | best synset: Synset('matronymic.n.01')
#    Synset definition: a name derived from the name of your mother or a maternal ancestor
#  - trivial name.n | best synset: Synset('None')
#    Synset definition: None
#  - eponym.n | best synset: Synset('eponym.n.02')
#    Synset definition: the name derived from a person (real or imaginary)
#  - also known as.a | best synset: Synset('None')
#    Synset definition: None
#  - aka.a | best synset: Synset('None')
#    Synset definition: None
#  - go.v | best synset: Synset('survive.v.01')
#    Synset definition: continue to live through hardship or adversity
#  - nameless.a | best synset: Synset('nameless.s.01')
#    Synset definition: being or having an unknown or unnamed source
#  - known.a | best synset: Synset('know.v.04')
#    Synset definition: be familiar or acquainted with a person or an object
#  - so-called.a | best synset: Synset('alleged.s.02')
#    Synset definition: doubtful or suspect
#  - designated.a | best synset: Synset('indicate.v.02')
#    Synset definition: indicate a place, direction, person, or thing; either spatially or figuratively
#  - full name.n | best synset: Synset('None')
#    Synset definition: None
# ________________________________________________
#
# Title disambiguation: Controller_object | best synset: Synset('control.n.09')
# Synset definition: a mechanism that controls the operation of a machine
# Frame elements disambiguations:
#  - Control | best synset: Synset('dominance.n.02')
#    Synset definition: the state that exists when one person or group has power over another
#  - Use | best synset: Synset('use.v.01')
#    Synset definition: put into service; make work or employ for a particular purpose or for its inherent or natural purpose
#  - Creator | best synset: Synset('creator.n.02')
#    Synset definition: a person who grows or makes or invents things
#  - Time_of_creation | best synset: Synset('time.n.02')
#    Synset definition: a period of time considered as a resource under your control and sufficient to accomplish something
#  - Name | best synset: Synset('name.v.02')
#    Synset definition: give the name or identifying characteristics of; refer to by name or some other identifying characteristic property
#  - Type | best synset: Synset('type.n.06')
#    Synset definition: a small metal block bearing a raised character on one end; produces a printed character when inked and pressed on paper
#  - Material | best synset: Synset('material.n.01')
#    Synset definition: the tangible substance that goes into the makeup of a physical object
#  - Controlled_entity | best synset: Synset('manipulate.v.05')
#    Synset definition: control (others or oneself) or influence skillfully, usually to one's advantage
# Lexical units disambiguations:
#  - button.n | best synset: Synset('push_button.n.01')
#    Synset definition: an electrical switch operated by pressing
#  - board.n | best synset: Synset('control_panel.n.01')
#    Synset definition: electrical device consisting of a flat insulated surface that contains switches and dials and meters for controlling other electrical devices
#  - knob.n | best synset: Synset('knob.n.04')
#    Synset definition: an ornament in the shape of a ball on the hilt of a sword or dagger
#  - switch.n | best synset: Synset('switch.n.01')
#    Synset definition: control consisting of a mechanical or electrical or electronic device for making or breaking or changing the connections in a circuit
#  - control.n | best synset: Synset('dominance.n.02')
#    Synset definition: the state that exists when one person or group has power over another
#  - switchboard.n | best synset: Synset('switchboard.n.01')
#    Synset definition: telephone central where circuits are completed with patchcords
# ________________________________________________
#
# Title disambiguation: Measure_area | best synset: Synset('standard.n.01')
# Synset definition: a basis for comparison; a reference point against which other things can be evaluated
# Frame elements disambiguations:
#  - Unit | best synset: Synset('unit.n.02')
#    Synset definition: an individual or group or structure or other entity regarded as a structural or functional constituent of a whole
#  - Area | best synset: Synset('area.n.03')
#    Synset definition: a part of an animal that has a special function or is supplied by a given artery or nerve
#  - Count | best synset: Synset('count.v.08')
#    Synset definition: have faith or confidence in
#  - Occupant | best synset: Synset('resident.n.01')
#    Synset definition: someone who lives at a particular place for a prolonged period or who was born there
# Lexical units disambiguations:
#  - hectare.n | best synset: Synset('hectare.n.01')
#    Synset definition: (abbreviated `ha') a unit of surface area equal to 100 ares (or 10,000 square meters)
#  - acre.n | best synset: Synset('acre.n.01')
#    Synset definition: a unit of area (4840 square yards) used in English-speaking countries
# ________________________________________________
